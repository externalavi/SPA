# %% [markdown]
# .mtx stands for matrix market format. A sparse matrix representation of the graph

# %%
import time
from pathlib import Path
from scipy.io import mmread

import networkx as nx
from Greedy_SOSP_2 import Greedy_SOSP
from Robust_MOSP_2 import Robust_MOSP

# %%
data_path = Path('data')/'road-road-usa.mtx'
G = nx.from_scipy_sparse_array(
    mmread(data_path),
    create_using=nx.DiGraph()
)

print('Loaded graph: nodes=', G.number_of_nodes(), 'edges=', G.number_of_edges())
